# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = 0
g = 0
L=10
x=np.arange(L)
y=np.zeros(L)
for n in range(0, L ):
    y[n] = x[n] + f
    f = -x[n] + 0.5 * y[n] -f
plt.plot(x,y);

# %%
f
# Out:
# -3.0
